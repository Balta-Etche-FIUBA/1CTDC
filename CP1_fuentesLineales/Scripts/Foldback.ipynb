# %% [markdown]
# ## Cálculo de resistencias para Foldback
#
# Se utilizan las ecuaciones de las diaposotivas, teniendo en cuenta que la variable R1/R2 se la llama __rel_resistencias__
#
# R1, R2 y Rs son las incógnitas pero a R2 se le puede dar un valor, por ejemplo, 1k ohm

# %%
vbe= 0.61452 #valor medido con rl = 3.3 (pico de corriente)
vbe= 0.52417
vbe= 0.6
vbe= 0.6
Vo = 5
Icc = 0.4
Imax = 1.5
R2 = 2170

# %%
Rs = (vbe*Vo)/(Vo*Icc+Icc*vbe-Imax*vbe)

rel_resistencias = ((Rs * Icc)/vbe )-1
R1 = rel_resistencias * R2

T
print(Rs)
print(R1)
print(rel_resistencias)
# Out:
# 2.238805970149253
# 1068.805970149253
# 0.49253731343283547

# %%
icc=0.422
io = 1.464
io_p=1.5
icc_p=0.4

error_1 = (icc-icc_p)*100/icc_p
error_2 = (io-io_p)*100/io_p

print(error_1)
print(error_2)
# Out:
# 5.499999999999991
# -2.400000000000002
